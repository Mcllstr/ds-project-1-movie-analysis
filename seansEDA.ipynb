# %%
# !ls
# Out:
# LICENSE                      imdb.title.principals.csv.gz
# LoadData.ipynb               imdb.title.ratings.csv.gz
# Project1.ipynb               rt.movie_info.tsv.gz
# README.md                    rt.reviews.tsv.gz
# bom.movie_gross.csv.gz       seansEDA.ipynb
# imdb.name.basics.csv.gz      tc-first-feature.ipynb
# imdb.title.akas.csv.gz       test_text_file.txt
# imdb.title.basics.csv.gz     tmdb.movies.csv.gz
# imdb.title.crew.csv.gz       tn.movie_budgets.csv.gz

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
bom_movie_gross = pd.read_csv("bom.movie_gross.csv.gz")
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
imdb_name_basics = pd.read_csv("imdb.name.basics.csv.gz")
imdb_name_basics.head(10)
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
# 5  nm0062879     Ruel S. Bayani         NaN         NaN
# 6  nm0063198              Bayou         NaN         NaN
# 7  nm0063432      Stevie Be-Zet         NaN         NaN
# 8  nm0063618          Jeff Beal      1963.0         NaN
# 9  nm0063750    Lindsay Beamish         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
# ...

# %%
imdb_title_akas = pd.read_csv("imdb.title.akas.csv.gz")
imdb_title_akas.head(50)
# Out:
#      title_id  ordering                                    title region  \
# 0   tt0369610        10                            Джурасик свят     BG
# 1   tt0369610        11                        Jurashikku warudo     JP
# 2   tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3   tt0369610        13                  O Mundo dos Dinossauros     BR
# 4   tt0369610        14                           Jurassic World     FR
# 5   tt0369610        15                           Jurassic World     GR
# 6   tt0369610        16                           Jurassic World     IT
# 7   tt0369610        17                            Jurski svijet     HR
# 8   tt0369610        18                             Olam ha'Yura     IL
# 9   tt0369610        19           Jurassic World: Mundo Jurásico     MX
# 10  tt0369610         1          Jurassic World: Sauruste maailm     EE
# 11  tt0369610        20                           Jurassic World     SE
# ...

# %%
imdb_title_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
# title_id             331703 non-null object
# ordering             331703 non-null int64
# title                331703 non-null object
# region               278410 non-null object
# language             41715 non-null object
# types                168447 non-null object
# attributes           14925 non-null object
# is_original_title    331678 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
# !ls
# Out:
# LICENSE                      imdb.title.principals.csv.gz
# LoadData.ipynb               imdb.title.ratings.csv.gz
# Project1.ipynb               rt.movie_info.tsv.gz
# README.md                    rt.reviews.tsv.gz
# bom.movie_gross.csv.gz       seansEDA.ipynb
# imdb.name.basics.csv.gz      tc-first-feature.ipynb
# imdb.title.akas.csv.gz       test_text_file.txt
# imdb.title.basics.csv.gz     tmdb.movies.csv.gz
# imdb.title.crew.csv.gz       tn.movie_budgets.csv.gz

# %%
imdb_title_basics = pd.read_csv("imdb.title.basics.csv.gz")
imdb_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_crew = pd.read_csv("imdb.title.crew.csv.gz")
imdb_title_crew.head(10)
# Out:
#        tconst                      directors  \
# 0   tt0285252                      nm0899854
# 1   tt0438973                            NaN
# 2   tt0462036                      nm1940585
# 3   tt0835418                      nm0151540
# 4   tt0878654  nm0089502,nm2291498,nm2292011
# 5   tt0879859                      nm2416460
# 6   tt0996958                      nm2286991
# 7   tt0999913                      nm0527109
# 8  tt10003792                     nm10539228
# 9  tt10005130                     nm10540239
#
#                                    writers
# 0                                nm0899854
# 1                      nm0175726,nm1802864
# 2                                nm1940585
# 3                      nm0310087,nm0841532
# 4                                nm0284943
# 5                                      NaN
# 6                      nm2286991,nm2651190
# 7  nm0527109,nm0329051,nm0001603,nm0930684
# 8                               nm10539228
# ...

# %%
# !ls
# Out:
# LICENSE                      imdb.title.principals.csv.gz
# LoadData.ipynb               imdb.title.ratings.csv.gz
# Project1.ipynb               rt.movie_info.tsv.gz
# README.md                    rt.reviews.tsv.gz
# bom.movie_gross.csv.gz       seansEDA.ipynb
# imdb.name.basics.csv.gz      tc-first-feature.ipynb
# imdb.title.akas.csv.gz       test_text_file.txt
# imdb.title.basics.csv.gz     tmdb.movies.csv.gz
# imdb.title.crew.csv.gz       tn.movie_budgets.csv.gz

# %%
imdb_title_principals = pd.read_csv('imdb.title.principals.csv.gz')
imdb_title_principals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
imdb_title_ratings = pd.read_csv('imdb.title.ratings.csv.gz')
imdb_title_ratings.head(10)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# 5   tt1069246            6.2       326
# 6   tt1094666            7.0      1613
# 7   tt1130982            6.4       571
# 8   tt1156528            7.2       265
# 9   tt1161457            4.2       148

# %%
# !ls
# Out:
# LICENSE                      imdb.title.principals.csv.gz
# LoadData.ipynb               imdb.title.ratings.csv.gz
# Project1.ipynb               rt.movie_info.tsv.gz
# README.md                    rt.reviews.tsv.gz
# bom.movie_gross.csv.gz       seansEDA.ipynb
# imdb.name.basics.csv.gz      tc-first-feature.ipynb
# imdb.title.akas.csv.gz       test_text_file.txt
# imdb.title.basics.csv.gz     tmdb.movies.csv.gz
# imdb.title.crew.csv.gz       tn.movie_budgets.csv.gz

# %%
# !ls
# Out:
# LICENSE                      imdb.title.principals.csv.gz
# LoadData.ipynb               imdb.title.ratings.csv.gz
# Project1.ipynb               rt.movie_info.tsv.gz
# README.md                    rt.reviews.tsv.gz
# bom.movie_gross.csv.gz       seansEDA.ipynb
# imdb.name.basics.csv.gz      tc-first-feature.ipynb
# imdb.title.akas.csv.gz       test_text_file.txt
# imdb.title.basics.csv.gz     tmdb.movies.csv.gz
# imdb.title.crew.csv.gz       tn.movie_budgets.csv.gz

# %%
rt_movie_info = pd.read_csv('rt.movie_info.tsv.gz',delimiter='\t')
rt_movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
rt_movie_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
# id              1560 non-null int64
# synopsis        1498 non-null object
# rating          1557 non-null object
# genre           1552 non-null object
# director        1361 non-null object
# writer          1111 non-null object
# theater_date    1201 non-null object
# dvd_date        1201 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         1530 non-null object
# studio          494 non-null object
# dtypes: int64(1), object(11)
# memory usage: 146.3+ KB

# %%
# !ls
# Out:
# LICENSE                      imdb.title.principals.csv.gz
# LoadData.ipynb               imdb.title.ratings.csv.gz
# Project1.ipynb               rt.movie_info.tsv.gz
# README.md                    rt.reviews.tsv.gz
# bom.movie_gross.csv.gz       seansEDA.ipynb
# imdb.name.basics.csv.gz      tc-first-feature.ipynb
# imdb.title.akas.csv.gz       test_text_file.txt
# imdb.title.basics.csv.gz     tmdb.movies.csv.gz
# imdb.title.crew.csv.gz       tn.movie_budgets.csv.gz

# %%
rt_reviews = pd.read_csv('rt.reviews.tsv.gz', delimiter='\t', encoding='latin-1')
rt_reviews.tail(50)
# Out:
#          id                                             review rating   fresh  \
# 54382  1999                                                NaN    2/5  rotten
# 54383  1999                                                NaN    2/5  rotten
# 54384  1999                                                NaN    1/5  rotten
# 54385  1999                                                NaN    3/5   fresh
# 54386  1999                                                NaN    2/5  rotten
# 54387  1999                                                NaN    3/5   fresh
# 54388  1999                                                NaN    2/5  rotten
# 54389  1999                                                NaN    3/5   fresh
# 54390  1999                                                NaN    2/5  rotten
# 54391  1999                                                NaN    1/5  rotten
# 54392  1999                                                NaN    3/5   fresh
# ...

# %%
rt_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
# id            54432 non-null int64
# review        48869 non-null object
# rating        40915 non-null object
# fresh         54432 non-null object
# critic        51710 non-null object
# top_critic    54432 non-null int64
# publisher     54123 non-null object
# date          54432 non-null object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
tmdb_movies = pd.read_csv('tmdb.movies.csv.gz')
tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tmdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
# !ls
# Out:
# LICENSE                      imdb.title.principals.csv.gz
# LoadData.ipynb               imdb.title.ratings.csv.gz
# Project1.ipynb               rt.movie_info.tsv.gz
# README.md                    rt.reviews.tsv.gz
# bom.movie_gross.csv.gz       seansEDA.ipynb
# imdb.name.basics.csv.gz      tc-first-feature.ipynb
# imdb.title.akas.csv.gz       test_text_file.txt
# imdb.title.basics.csv.gz     tmdb.movies.csv.gz
# imdb.title.crew.csv.gz       tn.movie_budgets.csv.gz

# %%
tn_movie_budgets = pd.read_csv('tn.movie_budgets.csv.gz')
tn_movie_budgets.head(35)
# Out:
#     id  release_date                                             movie  \
# 0    1  Dec 18, 2009                                            Avatar
# 1    2  May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 2    3   Jun 7, 2019                                      Dark Phoenix
# 3    4   May 1, 2015                           Avengers: Age of Ultron
# 4    5  Dec 15, 2017                 Star Wars Ep. VIII: The Last Jedi
# 5    6  Dec 18, 2015              Star Wars Ep. VII: The Force Awakens
# 6    7  Apr 27, 2018                            Avengers: Infinity War
# 7    8  May 24, 2007        Pirates of the Caribbean: At Worldâs End
# 8    9  Nov 17, 2017                                    Justice League
# 9   10   Nov 6, 2015                                           Spectre
# 10  11  Jul 20, 2012                             The Dark Knight Rises
# 11  12  May 25, 2018                           Solo: A Star Wars Story
# ...

# %%
tn_movie_budgets.tail(30)
# Out:
#       id  release_date                            movie production_budget  \
# 5752  53   Aug 1, 1991                          Slacker           $23,000
# 5753  54  Dec 31, 2014                        Dry Spell           $22,000
# 5754  55  Dec 31, 2003                         Flywheel           $20,000
# 5755  56   Jan 4, 2013         All Superheroes Must Die           $20,000
# 5756  57  Apr 21, 2015                    The Front Man           $20,000
# 5757  58   Dec 1, 2003                     Steel Spirit           $20,000
# 5758  59  Nov 25, 2011                       The Ridges           $17,300
# 5759  60   Jun 2, 2006                  The Puffy Chair           $15,000
# 5760  61   Apr 2, 2010                 Breaking Upwards           $15,000
# 5761  62  Dec 31, 2014             Stories of Our Lives           $15,000
# 5762  63  Apr 11, 1997                   Pink Flamingos           $12,000
# 5763  64  Apr 28, 2006         Grip: A Criminal's Story           $12,000
# ...

# %%
gross = pd.to_numeric(tn_movie_budgets.worldwide_gross.str.replace('$','').str.replace(',',''))

# %%
budget = pd.to_numeric(tn_movie_budgets.production_budget.str.replace('$','').str.replace(',',''))

# %%
roi = (gross - budget)/budget

# %%
roi.sort_values(ascending=False)
# Out:
# 5745    1799.000000
# 5613     497.750000
# 5492     430.517853
# 5679     415.564740
# 5406     412.833333
# 5709     341.058585
# 5346     311.354312
# 5773     290.704000
# 5676     262.921614
# 5210     224.000000
# 5536     214.384615
# 5715     207.530120
# 5665     188.803136
# 5372     179.180180
# 5781     163.582727
# 5656     154.490873
# 5742     143.231111
# 5612     124.000000
# 5117     123.277880
# 5357     121.500000
# 5774     119.275143
# 5746     114.346440
# 5507     114.306782
# 5430     110.037282
# 5424     107.644729
# 5680     101.431590
# 5211     100.759490
# 5655     100.333333
# 4567      99.134665
# 5677      99.000000
#            ...
# 4068      -1.000000
# 4067      -1.000000
# 5520      -1.000000
# 951       -1.000000
# 5491      -1.000000
# 5317      -1.000000
# 5750      -1.000000
# 5751      -1.000000
# 4413      -1.000000
# 5324      -1.000000
# 4414      -1.000000
# 3758      -1.000000
# 4069      -1.000000
# 5501      -1.000000
# ...

# %%
roi.max()
# Out:
# 1799.0

# %%
roi[roi==1799.0]
# Out:
# 5745    1799.0
# dtype: float64

# %%
tn_movie_budgets.iloc[5745]
# Out:
# id                             46
# release_date         Jun 30, 1972
# movie                 Deep Throat
# production_budget         $25,000
# domestic_gross        $45,000,000
# worldwide_gross       $45,000,000
# Name: 5745, dtype: object

# %%
tn_movie_budgets.iloc[5613]
# Out:
# id                             14
# release_date         Mar 21, 1980
# movie                     Mad Max
# production_budget        $200,000
# domestic_gross         $8,750,000
# worldwide_gross       $99,750,000
# Name: 5613, dtype: object

# %%
mask = (pd.to_datetime(tn_movie_budgets.release_date) >= '2010-01-01') & (pd.to_datetime(tn_movie_budgets.release_date) < '2019-01-01')

# %%
tn_movie_budgets_clip = tn_movie_budgets[mask]

# %%
gross_clip = pd.to_numeric(tn_movie_budgets_clip.worldwide_gross.str.replace('$','').str.replace(',',''))

# %%
budget_clip = pd.to_numeric(tn_movie_budgets_clip.production_budget.str.replace('$','').str.replace(',',''))

# %%
roi_clip = (gross_clip - budget_clip)/budget_clip

# %%
roi_clip.sort_values(ascending=False)
# Out:
# 5679    415.564740
# 5211    100.759490
# 5062     65.580591
# 5213     63.364198
# 4664     58.170677
# 4249     54.792961
# 5189     54.458341
# 4248     50.073590
# 3517     43.895652
# 5063     42.497008
# 5217     41.411721
# 4250     40.407969
# 4083     38.517372
# 5014     37.981056
# 4252     31.384303
# 3755     30.016276
# 5358     29.532711
# 4666     29.422194
# 4254     28.761302
# 4668     28.242602
# 2996     27.721411
# 4258     27.563598
# 5685     26.697820
# 4590     26.179241
# 5216     25.887177
# 5672     24.754942
# 3342     24.597236
# 3535     24.490067
# 3245     24.482055
# 4257     24.002052
#            ...
# 5205     -1.000000
# 5204     -1.000000
# 5113     -1.000000
# 5114     -1.000000
# 5115     -1.000000
# 5116     -1.000000
# 4414     -1.000000
# 5125     -1.000000
# 5126     -1.000000
# 5127     -1.000000
# 4413     -1.000000
# 4399     -1.000000
# 5144     -1.000000
# 5145     -1.000000
# 5155     -1.000000
# 4398     -1.000000
# ...

# %%
tn_movie_budgets_clip['roi'] = roi_clip
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tn_movie_budgets_clip.shape#.sort_values('roi', ascending=False)
# Out:
# (2124, 7)

# %%
type(tn_movie_budgets_clip['movie'].loc[5322])
# Out:
# str

# %%
tn_movie_budgets_clip.join(imdb_name_basics, how = 'inner', on)

# %%
tn_movie_budgets_clip.set_index('movie', inplace=True)

# %%
tn_movie_budgets_clip
# Out:
#                                                   id  release_date  \
# movie
# Pirates of the Caribbean: On Stranger Tides        2  May 20, 2011
# Avengers: Age of Ultron                            4   May 1, 2015
# Star Wars Ep. VIII: The Last Jedi                  5  Dec 15, 2017
# Star Wars Ep. VII: The Force Awakens               6  Dec 18, 2015
# Avengers: Infinity War                             7  Apr 27, 2018
# Justice League                                     9  Nov 17, 2017
# Spectre                                           10   Nov 6, 2015
# The Dark Knight Rises                             11  Jul 20, 2012
# Solo: A Star Wars Story                           12  May 25, 2018
# The Lone Ranger                                   13   Jul 2, 2013
# John Carter                                       14   Mar 9, 2012
# Tangled                                           15  Nov 24, 2010
# Captain America: Civil War                        17   May 6, 2016
# ...

# %%
imdb_title_basics.set_index('primary_title', inplace = True)

# %%
imdb_title_basics
# Out:
#                                                        tconst  \
# primary_title
# Sunghursh                                           tt0063540
# One Day Before the Rainy Season                     tt0066787
# The Other Side of the Wind                          tt0069049
# Sabse Bada Sukh                                     tt0069204
# The Wandering Soap Opera                            tt0100275
# A Thin Life                                         tt0111414
# Bigfoot                                             tt0112502
# Joe Finds Grace                                     tt0137204
# O Silêncio                                          tt0139613
# Nema aviona za Zagreb                               tt0144449
# Pál Adrienn                                         tt0146592
# So Much for Justice!                                tt0154039
# Cooper and Hemingway: The True Gen                  tt0159369
# Children of the Green Dragon                        tt0162942
# ...

# %%
the_df.fillna('Unknown', inplace = True)

# %%
#the_df = tn_movie_budgets_clip.join(imdb_title_basics, how = 'inner')
the_df
# Out:
#                                     id  release_date production_budget  \
# #Horror                             16  Nov 20, 2015        $1,500,000
# 10 Cloverfield Lane                 54  Mar 11, 2016        $5,000,000
# 10 Days in a Madhouse               48  Nov 11, 2015       $12,000,000
# 12 Strong                           64  Jan 19, 2018       $35,000,000
# 12 Years a Slave                    18  Oct 18, 2013       $20,000,000
# 127 Hours                            6   Nov 5, 2010       $18,000,000
# 13 Sins                             51  Apr 18, 2014        $4,000,000
# 1982                                23   Mar 1, 2016        $1,000,000
# 1982                                23   Mar 1, 2016        $1,000,000
# 2 Guns                              39   Aug 2, 2013       $61,000,000
# 21 Jump Street                      44  Mar 16, 2012       $42,000,000
# 22 Jump Street                      85  Jun 13, 2014       $50,000,000
# ...

# %%
horror_df = the_df[the_df['genres'].str.contains('Horror')]

# %%
copy_nan = the_df[the_df['worldwide_gross'] == '$0']

# %%
for index, element in enumerate(the_df['roi']):
    if (element < -0.9999999) & (element > -1.01):
        the_df['roi'][index] = np.nan
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
the_df['genres'].fillna('Empty')
# Out:
# #Horror                                       Crime,Drama,Horror
# 10 Cloverfield Lane                         Drama,Horror,Mystery
# 10 Days in a Madhouse                                      Drama
# 12 Strong                                   Action,Drama,History
# 12 Years a Slave                         Biography,Drama,History
# 127 Hours                              Adventure,Biography,Drama
# 13 Sins                                          Horror,Thriller
# 1982                                                       Drama
# 1982                                                 Documentary
# 2 Guns                                       Action,Comedy,Crime
# 21 Jump Street                               Action,Comedy,Crime
# 22 Jump Street                               Action,Comedy,Crime
# 23 Blast                                      Drama,Family,Sport
# 3                                           Comedy,Drama,Romance
# ...

# %%
horror_df = the_df[the_df['genres'].str.contains('Horror')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-666fc1bddabb> in <module>
# ----> 1 horror_df = the_df[the_df['genres'].str.contains('Horror')]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
# -> 2917         if com.is_bool_indexer(key):
#    2918             return self._getitem_bool_array(key)
#    2919
#
# /usr/local/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     122             if not lib.is_bool_array(key):
#     123                 if isna(key).any():
# --> 124                     raise ValueError(na_msg)
#     125                 return False
#     126             return True
#
# ValueError: cannot index with vector containing NA / NaN values

# %%
the_df['genres'].fillna('Empty', inplace=True)

# %%
horror_df = the_df[the_df['genres'].str.contains('Horror')]

# %%
horror_df['roi'].plot(kind='box', ylim =(-10, 80))
plt.title('Horror ROI')
plt.ylabel('ROI')
# Out:
# Text(0, 0.5, 'ROI')
